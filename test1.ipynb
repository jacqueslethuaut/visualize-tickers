# %%
import sys
sys.path.insert(0, "./ticker_analysis")

from finance import get_history_and_plot

import datetime
import config

# %%
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2023, 12, 31)

df = get_history_and_plot('AAPL', 'av-daily-adjusted', start, end, config.ALPHAVANTAGE_API_KEY)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/venv-metal/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniconda3/envs/venv-metal/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/venv-metal/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Open'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/jacqueslethuaut/Dev/git/Master/visualize-tickers/test1.ipynb Cell 2 in 4
#       <a href='vscode-notebook-cell:/Users/jacqueslethuaut/Dev/git/Master/visualize-tickers/test1.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> start = datetime.datetime(2020, 1, 1)
#       <a href='vscode-notebook-cell:/Users/jacqueslethuaut/Dev/git/Master/visualize-tickers/test1.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> end = datetime.datetime(2023, 12, 31)
# ----> <a href='vscode-notebook-cell:/Users/jacqueslethuaut/Dev/git/Master/visualize-tickers/test1.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> df = get_history_and_plot('AAPL', 'av-daily-adjusted', start, end, config.ALPHAVANTAGE_API_KEY)
#
# File ~/Dev/git/Master/visualize-tickers/./ticker_analysis/finance.py:19, in get_history_and_plot(ticker, period, start, end, key)
#      13 data = get_history(ticker, period, start, end, key)
#      15 fig = go.Figure()
#      17 fig = go.Figure(data=[go.Candlestick(
#      18     x=data.index,
# ---> 19     open=data['Open'],
#      20     high=data['High'],
#      21     low=data['Low'],
#      22     close=data['Close'],
#      23     increasing_line_color= 'cyan', decreasing_line_color= 'gray'
#      24 )])
#      26 fig.update_layout(
#      27     xaxis_rangeslider_visible=True,
#      28     title='AAPL : Prix à la fermeture par jour',
#      29     yaxis_title='AAPL Stock',
#      30 )
#      32 fig.show()
#
# File ~/miniconda3/envs/venv-metal/lib/python3.9/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~/miniconda3/envs/venv-metal/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Open'

# %%
df
# Out:
#               open      high      low   close  adjusted close    volume  \
# 2020-01-02  296.24  300.6000  295.190  300.35       73.346799  33911864
# 2020-01-03  297.15  300.5800  296.500  297.43       72.633722  36633878
# 2020-01-06  293.79  299.9600  292.750  299.80       73.212487  29644644
# 2020-01-07  299.84  300.9000  297.480  298.39       72.868158  27877655
# 2020-01-08  297.16  304.4400  297.160  303.19       74.040340  33090946
# ...            ...       ...      ...     ...             ...       ...
# 2023-05-22  173.98  174.7100  173.450  174.20      174.200000  43570932
# 2023-05-23  173.13  173.3794  171.275  171.56      171.560000  50747263
# 2023-05-24  171.09  172.4183  170.520  171.84      171.840000  45143488
# 2023-05-25  172.41  173.8950  171.690  172.99      172.990000  56058258
# 2023-05-26  173.32  175.7700  173.110  175.43      175.430000  54834975
#
#             dividend amount  split coefficient
# 2020-01-02              0.0                1.0
# 2020-01-03              0.0                1.0
# 2020-01-06              0.0                1.0
# 2020-01-07              0.0                1.0
# 2020-01-08              0.0                1.0
# ...                     ...                ...
# 2023-05-22              0.0                1.0
# 2023-05-23              0.0                1.0
# 2023-05-24              0.0                1.0
# 2023-05-25              0.0                1.0
# 2023-05-26              0.0                1.0
#
# [857 rows x 8 columns]
