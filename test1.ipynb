# %%
# %load_ext autoreload
# %autoreload 2

# %%
import config

from ticker_analysis import finance
from ticker_analysis.finance import FinanceApp

# %%
app = FinanceApp()
data = app.get_stock_data(symbol='AAPL', period='daily_adjusted', api_key=config.ALPHAVANTAGE_API_KEY)
app.show()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
data.describe().T
# Out:
#                        count          mean           std            min  \
# 1. open               5933.0  1.731190e+02  1.512555e+02      12.990000
# 2. high               5933.0  1.750582e+02  1.525043e+02      13.190000
# 3. low                5933.0  1.710696e+02  1.498015e+02      12.720000
# 4. close              5933.0  1.731220e+02  1.511893e+02      13.120000
# 5. adjusted close     5933.0  3.069183e+01  4.562353e+01       0.199104
# 6. volume             5933.0  3.163808e+07  3.011683e+07  702500.000000
# 7. dividend amount    5933.0  7.048711e-03  1.160089e-01       0.000000
# 8. split coefficient  5933.0  1.001854e+00  8.899272e-02       1.000000
# return                5932.0  1.221390e-03  9.106181e-02      -0.122075
# volatility            5912.0  3.013938e-02  8.607047e-02       0.004557
#
#                                25%           50%           75%           max
# 1. open               7.108000e+01  1.312500e+02  2.019200e+02  7.024100e+02
# ...
